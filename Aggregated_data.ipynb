# %%
# Import necessary libraries
import pandas as pd
import glob

# %%
# Folder where the csv files are located
folder_path = r'C:\Users\Ernie\Documents\GitHub\Citi Bike Viz\Resources\\'

# %%
# Find all csv files in the folder
csv_files = glob.glob(folder_path + "*.csv")

# %%
# List to store DataFrames
dfs = []

# Loop through each file and aggregate 100 rows
for file in csv_files:
    df=pd.read_csv(file)
    df_sample = df.sample(100)
    dfs.append(df_sample)
# Out:
# C:\Users\Ernie\AppData\Local\Temp\ipykernel_24612\3231143352.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file)

# %%
# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)
final_df.head(10)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  8886EF8C9BD07586  electric_bike  2024-05-06 13:57:24  2024-05-06 14:09:04
# 1  7DA49CAE12D5AD44  electric_bike  2024-05-26 10:27:04  2024-05-26 10:36:41
# 2  24EE0168B758EECA   classic_bike  2024-05-13 11:51:21  2024-05-13 11:56:29
# 3  84D7596D27A0BB58   classic_bike  2024-05-30 06:57:31  2024-05-30 07:03:39
# 4  BEA997A296AC0F88  electric_bike  2024-05-11 00:39:24  2024-05-11 00:43:15
# 5  38FE674F69FCA25D  electric_bike  2024-05-04 19:01:55  2024-05-04 19:04:43
# 6  8687910C64FBEF5F   classic_bike  2024-05-29 20:32:22  2024-05-29 20:38:13
# 7  D629B29BD8E909FC  electric_bike  2024-05-28 15:15:03  2024-05-28 15:15:44
# 8  F97A97A2D565900A  electric_bike  2024-05-07 17:00:36  2024-05-07 17:11:11
# 9  233FAFDDC92C55DF   classic_bike  2024-05-30 20:29:59  2024-05-30 20:50:04
#
#                    start_station_name start_station_id  \
# 0                    W 34 St & 11 Ave          6578.01
# 1                     E 95 St & 3 Ave          7365.13
# 2              Norfolk St & Broome St          5374.01
# 3                  Broadway & W 41 St          6560.01
# 4                      E 2 St & Ave B          5515.02
# 5                Roebling St & N 4 St          5267.09
# 6                Warren St & Smith St          4371.01
# 7  Frederick Douglass Blvd & W 145 St          7954.12
# 8                     W 24 St & 7 Ave          6257.03
# 9           Marcy Ave & Lafayette Ave          4476.03
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# 0                     1 Ave & E 44 St        6379.03  40.756185 -74.002590
# 1                     3 Ave & E 62 St        6762.04  40.784904 -73.950526
# 2                Division St & Bowery        5270.08  40.717227 -73.988021
# 3                  E 47 St & Park Ave        6584.12  40.755136 -73.986580
# 4                 Mott St & Prince St        5561.04  40.722165 -73.983829
# 5             Grand St & Havemeyer St        5267.08  40.714686 -73.957398
# 6                 St Marks Pl & 4 Ave        4249.01  40.685424 -73.991278
# 7  Frederick Douglass Blvd & W 145 St        7954.12  40.823134 -73.941678
# 8              N Moore St & Hudson St        5470.02  40.744878 -73.995263
# 9                 Broadway & Berry St        5164.05  40.690081 -73.947915
#
#      end_lat    end_lng member_casual start_date start_time end_date end_time
# 0  40.750020 -73.969053        member        NaN        NaN      NaN      NaN
# 1  40.763126 -73.965269        member        NaN        NaN      NaN      NaN
# 2  40.714193 -73.996732        member        NaN        NaN      NaN      NaN
# 3  40.755103 -73.974987        member        NaN        NaN      NaN      NaN
# 4  40.723180 -73.994800        member        NaN        NaN      NaN      NaN
# 5  40.712868 -73.956981        casual        NaN        NaN      NaN      NaN
# 6  40.681970 -73.980340        member        NaN        NaN      NaN      NaN
# 7  40.823061 -73.941928        member        NaN        NaN      NaN      NaN
# 8  40.719961 -74.008443        member        NaN        NaN      NaN      NaN
# 9  40.710361 -73.965304        member        NaN        NaN      NaN      NaN

# %%
# SAve the aggreagated data to a new CSV file
final_df.to_csv(r'C:\Users\Ernie\Documents\GitHub\Citi Bike Viz\Resources\aggregated_sample.csv', index=False)

# %% [markdown]
# Split Date and Time

# %%
# Load the csv file
df_aggregated_sample = pd.read_csv(r'C:\Users\Ernie\Documents\GitHub\Citi Bike Viz\Resources\aggregated_sample.csv')

# %%
# Convert 'started_at' and 'ended_at' columns to datetime format
df_aggregated_sample['started_at']= pd.to_datetime(df_aggregated_sample['started_at'])
df_aggregated_sample['ended_at'] = pd.to_datetime(df_aggregated_sample['ended_at'])

# %%
# Extract the date and time parts
df_aggregated_sample['start_date'] = df_aggregated_sample ['started_at'].dt.date
df_aggregated_sample['start_time'] =df_aggregated_sample ['started_at'].dt.time
df_aggregated_sample['end_date'] = df_aggregated_sample['ended_at'].dt.date
df_aggregated_sample['end_time'] = df_aggregated_sample['ended_at'].dt.time

# %%
# Save the updated DataFrame back to a new CSV file
df_aggregated_sample.to_csv(r'C:\Users\Ernie\Documents\GitHub\Citi Bike Viz\Resources\updated_file.csv', index=False)
